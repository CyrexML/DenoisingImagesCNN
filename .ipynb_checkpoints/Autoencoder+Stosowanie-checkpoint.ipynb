# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from keras import layers
from sklearn.model_selection import train_test_split

# %%
# Ścieżki do danych
data_dir = "D:/labSem6/Obrazy3"
clean_data_dir = os.path.join(data_dir, "ObrazyCzyste")
noisy_data_dir = os.path.join(data_dir, "ObrazySzum")

# Wczytanie obrazów czystych
clean_images = os.listdir(clean_data_dir)
x_train_clean = []
for image_file in clean_images:
    image_path = os.path.join(clean_data_dir, image_file)
    image = plt.imread(image_path)
    x_train_clean.append(image)
x_train_clean = np.array(x_train_clean)

# Wczytanie obrazów zaszumionych
noisy_images = os.listdir(noisy_data_dir)
x_train_noisy = []
for image_file in noisy_images:
    image_path = os.path.join(noisy_data_dir, image_file)
    image = plt.imread(image_path)
    x_train_noisy.append(image)
x_train_noisy = np.array(x_train_noisy)

# %%
# Normalizacja danych
x_train_clean = x_train_clean / 255.0
x_train_noisy = x_train_noisy / 255.0

# %%
# Wybór 5 przykładów
selected_examples = x_train_noisy[:5]

# Wyświetlenie 5 obrazów (zawierających szum i czyste)
fig, axes = plt.subplots(2, 5, figsize=(15, 6))

# Wyświetlanie obrazów zawierających szum
for i, example in enumerate(selected_examples):
    axes[0, i].imshow(example)
    axes[0, i].axis('off')
    axes[0, i].set_title('Zawierający szum')

# Wyświetlanie czystych obrazów
for i, example in enumerate(selected_examples):
    clean_example = x_train_clean[i]
    axes[1, i].imshow(clean_example)
    axes[1, i].axis('off')
    axes[1, i].set_title('Czysty')

plt.show()

# %%
# Podział na zbiór treningowy i testowy
train_ratio = 0.8
x_train_clean, x_test_clean, x_train_noisy, x_test_noisy = train_test_split(x_train_clean, x_train_noisy,
                                                                            test_size=1 - train_ratio, random_state=42)

# Wyświetlenie informacji o liczbie obrazów treningowych i testowych
print("Liczba obrazów treningowych:", len(x_train_clean))
print("Liczba obrazów testowych:", len(x_test_clean))
# Out:
# Liczba obrazów treningowych: 646
# Liczba obrazów testowych: 162

# %%
def create_model():
  x = tf.keras.Input(shape=(500, 500, 3))
# Encoder
  e_conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
  pool1 = layers.MaxPooling2D((2, 2), padding='same')(e_conv1)
  batchnorm_1 = layers.BatchNormalization()(pool1)
  e_conv2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(batchnorm_1)
  h = layers.MaxPooling2D((2, 2), padding='same')(e_conv2)
# Decoder
  d_conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(h)
  up1 = layers.UpSampling2D((2, 2))(d_conv1)
  d_conv2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(up1)
  up2 = layers.UpSampling2D((2, 2))(d_conv2)

  r = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(up2)
  model = tf.keras.Model(x, r)
  model.compile(optimizer='adam', loss='mse')
  return model
gaussian_auto_encoder = create_model()
gaussian_auto_encoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 500, 500, 3)]     0
#
#  conv2d_18 (Conv2D)          (None, 500, 500, 64)      1792
#
#  max_pooling2d_7 (MaxPooling  (None, 250, 250, 64)     0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 250, 250, 64)     256
#  hNormalization)
#
#  conv2d_19 (Conv2D)          (None, 250, 250, 32)      18464
#
#  max_pooling2d_8 (MaxPooling  (None, 125, 125, 32)     0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 125, 125, 64)      18496
#
#  up_sampling2d_8 (UpSampling  (None, 250, 250, 64)     0
#  2D)
#
#  conv2d_21 (Conv2D)          (None, 250, 250, 32)      18464
#
#  up_sampling2d_9 (UpSampling  (None, 500, 500, 32)     0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 500, 500, 3)       867
#
# =================================================================
# Total params: 58,339
# Trainable params: 58,211
# Non-trainable params: 128
# _________________________________________________________________

# %%
gaussian_early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
# Trenowanie modelu
history = gaussian_auto_encoder.fit(x_train_noisy, x_train_clean, epochs=25, batch_size=33, validation_split=0.2, callbacks=[gaussian_early_stop])
# Out:
# Epoch 1/25
# 33/33 [==============================] - 252s 7s/step - loss: 0.0164 - val_loss: 0.0693
# Epoch 2/25
# 33/33 [==============================] - 217s 7s/step - loss: 0.0095 - val_loss: 0.0619
# Epoch 3/25
# 33/33 [==============================] - 216s 7s/step - loss: 0.0079 - val_loss: 0.0562
# Epoch 4/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0075 - val_loss: 0.0507
# Epoch 5/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0071 - val_loss: 0.0449
# Epoch 6/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0069 - val_loss: 0.0398
# Epoch 7/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0070 - val_loss: 0.0347
# Epoch 8/25
# 33/33 [==============================] - 214s 6s/step - loss: 0.0065 - val_loss: 0.0307
# Epoch 9/25
# 33/33 [==============================] - 214s 6s/step - loss: 0.0065 - val_loss: 0.0255
# Epoch 10/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0079 - val_loss: 0.0197
# Epoch 11/25
# 33/33 [==============================] - 214s 6s/step - loss: 0.0061 - val_loss: 0.0168
# Epoch 12/25
# 33/33 [==============================] - 214s 6s/step - loss: 0.0061 - val_loss: 0.0128
# Epoch 13/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0060 - val_loss: 0.0109
# Epoch 14/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0058 - val_loss: 0.0094
# Epoch 15/25
# 33/33 [==============================] - 214s 6s/step - loss: 0.0063 - val_loss: 0.0075
# Epoch 16/25
# 33/33 [==============================] - 215s 7s/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 17/25
# 33/33 [==============================] - 214s 6s/step - loss: 0.0060 - val_loss: 0.0062

# %%
# import pickle
# # Zapisanie modelu
# with open('model.pkl', 'wb') as file:
#     pickle.dump(autoencoder, file)

# %%
# # Odczytanie modelu
# with open('model.pkl', 'rb') as file:
#     autoencoder = pickle.load(file)

# %%
# Ocena modelu na danych testowych
loss = gaussian_auto_encoder.evaluate(x_test_noisy, x_test_clean)
print("Błąd rekonstrukcji na danych testowych:", loss)
# Out:
# 6/6 [==============================] - 13s 2s/step - loss: 0.0063
# Błąd rekonstrukcji na danych testowych: 0.006267748307436705

# %%
# Narysowanie wykresu straty
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# Uzyskiwanie zrekonstruowanych obrazów
x_new_clean = gaussian_auto_encoder.predict(x_train_noisy)

# Wybieranie losowych 5 indeksów obrazów
random_indices = random.sample(range(len(x_train_noisy)), 5)

# Wyświetlanie oryginalnych obrazów, obrazów z szumem i zrekonstruowanych obrazów
fig, axes = plt.subplots(nrows=3, ncols=len(random_indices), figsize=(12, 9))
for i, index in enumerate(random_indices):
    original_noisy_image = x_train_noisy[index]
    original_clean_image = x_train_clean[index]
    reconstructed_image = x_new_clean[index]

    # zaszumione
    axes[0, i].imshow(original_noisy_image)
    axes[0, i].set_title("Oryginalne zaszumione")
    axes[0, i].axis("off")

    # oryginalne czyste
    axes[1, i].imshow(original_clean_image)
    axes[1, i].set_title("Oryginalne czyste")
    axes[1, i].axis("off")

    # rekonstruowane czyste
    axes[2, i].imshow(reconstructed_image)
    axes[2, i].set_title("Rekonstruowane czyste")
    axes[2, i].axis("off")

plt.tight_layout()
plt.show()
# Out:
# 21/21 [==============================] - 56s 3s/step
